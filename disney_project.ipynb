# %%
# Note: This is a disney dataset found on Kaggle.com

# Question
#1. What film type is played the most?
#2. What country does movies take place in the most?
#3. Correct the date format
#4. What is the latest movie/tv show made and in what year was m/tv made the most?
#5. Rating count (Try using pie chart if possible)
#6. What is the longest movie(NOT TV SHOW because it contains seasons)
#7. What tv show has the most seasons?
#8. What was the first disney movie/ tv show made?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('disney_plus_titles.csv')
df.head()
# Out:
#   show_id     type                           title  \
# 0      s1    Movie                   A Spark Story
# 1      s2    Movie                  Spooky Buddies
# 2      s3    Movie          The Fault in Our Stars
# 3      s4  TV Show                 Dog: Impossible
# 4      s5  TV Show  Spidey And His Amazing Friends
#
#                      director  \
# 0  Jason Sterman, Leanne Dare
# 1                Robert Vince
# 2                  Josh Boone
# 3                         NaN
# 4                         NaN
#
#                                                 cast                country  \
# 0                      Apthon Corbin, Louis Gonzales                    NaN
# 1  Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...  United States, Canada
# 2  Shailene Woodley, Ansel Elgort, Laura Dern, Sa...          United States
# 3                                       Matt Beisner          United States
# 4  Benjamin Valic, Lily Sanfelippo, Jakari Fraser...          United States
#
# ...

# %%
sns.countplot(x=df['type'])
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %% [markdown]
# #### There are more disney movies than tv shows

# %%
plt.figure(figsize=(20,18))
sns.countplot(x=df['country'], order=df['country'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Most disney movies are made in the US alone

# %%
df.head(
)
# Out:
#   show_id     type                           title  \
# 0      s1    Movie                   A Spark Story
# 1      s2    Movie                  Spooky Buddies
# 2      s3    Movie          The Fault in Our Stars
# 3      s4  TV Show                 Dog: Impossible
# 4      s5  TV Show  Spidey And His Amazing Friends
#
#                      director  \
# 0  Jason Sterman, Leanne Dare
# 1                Robert Vince
# 2                  Josh Boone
# 3                         NaN
# 4                         NaN
#
#                                                 cast                country  \
# 0                      Apthon Corbin, Louis Gonzales                    NaN
# 1  Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...  United States, Canada
# 2  Shailene Woodley, Ansel Elgort, Laura Dern, Sa...          United States
# 3                                       Matt Beisner          United States
# 4  Benjamin Valic, Lily Sanfelippo, Jakari Fraser...          United States
#
# ...

# %%
# I convert the added date column to the correct format
df['date_added'] = pd.to_datetime(df['date_added'])

# %%
df['date_added'].max()
# Out:
# Timestamp('2021-09-24 00:00:00')

# %%
df[df['date_added'] == '2021-09-24']
# Out:
#   show_id   type                   title                    director  \
# 0      s1  Movie           A Spark Story  Jason Sterman, Leanne Dare
# 1      s2  Movie          Spooky Buddies                Robert Vince
# 2      s3  Movie  The Fault in Our Stars                  Josh Boone
#
#                                                 cast                country  \
# 0                      Apthon Corbin, Louis Gonzales                    NaN
# 1  Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...  United States, Canada
# 2  Shailene Woodley, Ansel Elgort, Laura Dern, Sa...          United States
#
#   date_added  release_year rating duration                      listed_in  \
# 0 2021-09-24          2021  TV-PG   88 min                    Documentary
# 1 2021-09-24          2011      G   93 min          Comedy, Fantasy, Kids
# 2 2021-09-24          2014  PG-13  127 min  Coming of Age, Drama, Romance
#
#                                          description
# ...

# %% [markdown]
# #### The latest disney movies were made in 24 Sept 2021 and it was 3 movies

# %%
tv = df[df['type'] == 'TV Show']

# %%
tv['date_added'].max()
# Out:
# Timestamp('2021-09-22 00:00:00')

# %%
tv[tv['date_added'] == '2021-09-22']
# Out:
#   show_id     type                           title director  \
# 3      s4  TV Show                 Dog: Impossible      NaN
# 4      s5  TV Show  Spidey And His Amazing Friends      NaN
# 5      s6  TV Show              Star Wars: Visions      NaN
#
#                                                 cast        country  \
# 3                                       Matt Beisner  United States
# 4  Benjamin Valic, Lily Sanfelippo, Jakari Fraser...  United States
# 5                                                NaN            NaN
#
#   date_added  release_year rating   duration  \
# 3 2021-09-22          2019  TV-PG  2 Seasons
# 4 2021-09-22          2021   TV-Y   1 Season
# 5 2021-09-22          2021  TV-PG   1 Season
#
#                               listed_in  \
# 3  Animals & Nature, Docuseries, Family
# 4     Action-Adventure, Animation, Kids
# 5    Action-Adventure, Animation, Anime
#
#                                          description
# ...

# %% [markdown]
# #### The latest TV shows were made in 22 Sept 2021 and it was 3 TV shows

# %%
df.head()
# Out:
#   show_id     type                           title  \
# 0      s1    Movie                   A Spark Story
# 1      s2    Movie                  Spooky Buddies
# 2      s3    Movie          The Fault in Our Stars
# 3      s4  TV Show                 Dog: Impossible
# 4      s5  TV Show  Spidey And His Amazing Friends
#
#                      director  \
# 0  Jason Sterman, Leanne Dare
# 1                Robert Vince
# 2                  Josh Boone
# 3                         NaN
# 4                         NaN
#
#                                                 cast                country  \
# 0                      Apthon Corbin, Louis Gonzales                    NaN
# 1  Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...  United States, Canada
# 2  Shailene Woodley, Ansel Elgort, Laura Dern, Sa...          United States
# 3                                       Matt Beisner          United States
# 4  Benjamin Valic, Lily Sanfelippo, Jakari Fraser...          United States
#
# ...

# %%
plt.figure(figsize=(10,8))
plt.pie(df['rating'].value_counts(), autopct='%1.1f%%', labels=['TV-G', 'TV-PG', 'G', 'PG', 'TV-Y7', 'TV-14', 'PG-13', 'TV-Y', 'TV-Y7-FV'])
plt.show()

# %% [markdown]
# #### The most rating counts for disney movies and Tv shows are TV-G which is 22,5% of the movies

# %%
movie = df[df['type'] == 'Movie']

# %%
movie['duration'].max()
# Out:
# '99 min'

# %%
# I stripped the 'min' from duration otherwise I cannot find the max value
movie['duration'] = df['duration'].str[:-3]
# Out:
# <ipython-input-31-747497afc891>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['duration'] = df['duration'].str[:-3]

# %%
movie['duration'] = movie['duration'].astype(int)
# Out:
# <ipython-input-34-48530a3b7453>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['duration'] = movie['duration'].astype(int)

# %%
movie['duration'].max()
# Out:
# 183

# %%
movie[movie['duration'] == 183]
# Out:
#     show_id   type                              title  \
# 965    s966  Movie  Marvel Studios' Avengers: Endgame
#
#                      director  \
# 965  Anthony Russo, Joe Russo
#
#                                                   cast        country  \
# 965  Robert Downey Jr., Chris Evans, Mark Ruffalo, ...  United States
#
#     date_added  release_year rating  duration  \
# 965 2019-11-12          2019  PG-13       183
#
#                                       listed_in  \
# 965  Action-Adventure, Fantasy, Science Fiction
#
#                                            description
# 965  The epic finale to the Infinity Saga, this dra...

# %% [markdown]
# #### The longest movie was 183 minutes

# %%
tv[tv['duration'] == '16 Seasons']
# Out:
#    show_id     type            title director  \
# 13     s14  TV Show  Life Below Zero      NaN
#
#                                                  cast        country  \
# 13  Chip Hailstone, Agnes Hailstone, Sue Aikens, A...  United States
#
#    date_added  release_year rating    duration  \
# 13 2021-09-15          2012  TV-14  16 Seasons
#
#                                          listed_in  \
# 13  Action-Adventure, Animals & Nature, Docuseries
#
#                                           description
# 13  Experience life deep in Alaska where the prima...

# %%
# I stripped the 'Seasons, Season, s' from the tv 'duration' column
tv['duration'] = tv['duration'].replace({'s':''}, regex=True)
# Out:
# <ipython-input-50-78302598b34d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv['duration'] = tv['duration'].replace({'s':''}, regex=True)

# %%
tv['duration']
# Out:
# 3        2
# 4        1
# 5        1
# 13      16
# 14       1
#        ...
# 1344     4
# 1360     3
# 1365     3
# 1366     2
# 1367     3
# Name: duration, Length: 377, dtype: object

# %%
# I could not find the max value because I noticed there was a empty string at the end
tv['duration'].max()
# Out:
# '9 '

# %%
tv['duration'] = tv['duration'].str[:-1]
# Out:
# <ipython-input-54-25766151ab7f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv['duration'] = tv['duration'].str[:-1]

# %%
# I converted it to an 'int', If i don't, I wont be able to find the max value
tv['duration'] = tv['duration'].astype(int)
# Out:
# <ipython-input-56-2085b346f59b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv['duration'] = tv['duration'].astype(int)

# %%
tv['duration'].max()
# Out:
# 31

# %%
tv[tv['duration'] == 31]
# Out:
#     show_id     type         title director  \
# 319    s320  TV Show  The Simpsons      NaN
#
#                                                   cast        country  \
# 319  Dan Castellaneta, Julie Kavner, Nancy Cartwrig...  United States
#
#     date_added  release_year rating  duration          listed_in  \
# 319 2020-10-02          1989  TV-PG        31  Animation, Comedy
#
#                                            description
# 319  The world’s favorite nuclear family, in the aw...

# %% [markdown]
# #### The longest TV show is the simpsons which contains 31 seasons

# %%
movie['release_year'].min()
# Out:
# 1928

# %%
movie[movie['release_year'] == 1928]
# Out:
#      show_id   type             title                director         cast  \
# 1146   s1147  Movie  Steamboat Willie  Walt Disney, Ub Iwerks  Walt Disney
#
#             country date_added  release_year rating  duration  \
# 1146  United States 2019-11-12          1928  TV-Y7         8
#
#                     listed_in  \
# 1146  Animation, Family, Kids
#
#                                             description
# 1146  Watch Mickey Mouse's classic cartoon debut. Se...

# %% [markdown]
# #### The first movie was made/ released in 1928

# %%
tv['release_year'].min()
# Out:
# 1955

# %%
tv[tv['release_year'] == 1955]
# Out:
#      show_id     type                             title director  \
# 997     s998  TV Show       Mickey Mouse Club (1955-59)      NaN
# 1170   s1171  TV Show  The Adventures of Spin and Marty      NaN
#
#                                cast        country date_added  release_year  \
# 997                             NaN  United States 2019-11-12          1955
# 1170  David Stollery, Tim Considine  United States 2019-11-12          1955
#
#      rating  duration                     listed_in  \
# 997   TV-PG         1               Family, Variety
# 1170   TV-G         1  Buddy, Coming of Age, Family
#
#                                             description
# 997   The Mickey Mouse Club is a variety show featur...
# 1170  Spin and Marty have adventures during the summ...

# %% [markdown]
# #### There was 2 TV shows was made/ released in 1955 which is the first 2 TV shows made
